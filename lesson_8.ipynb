# %%
import numpy as np
from scipy import stats

# %% [markdown]
# ## Задача 1
# Провести дисперсионный анализ для определения того, есть ли различия среднего роста среди взрослых футболистов, хоккеистов и штангистов.
# Даны значения роста в трех группах случайно выбранных спортсменов:
# Футболисты: 173, 175, 180, 178, 177, 185, 183, 182
# Хоккеисты: 177, 179, 180, 188, 177, 172, 171, 184, 180
# Штангисты: 172, 173, 169, 177, 166, 180, 178, 177, 172, 166, 170

# %%
# H0 - не существует различий в среднем росте среди спортсменов разных видов спорта
# H1 - существуют различия в среднем росте среди спортсменов разных видов спорта

y1 = np.array([173, 175, 180, 178, 177, 185, 183, 182])
y2 = np.array([177, 179, 180, 188, 177, 172, 171, 184, 180])
y3 = np.array([172, 173, 169, 177, 166, 180, 178, 177, 172, 166, 170])

f_stat, p_value = stats.f_oneway(y1, y2, y3)

print(f'Т.к. p_value = {p_value:.5f}, то для уровня значимости a = 5% \n\
можно сказать, что есть различия в росте между спортсмена разных видов спорта\n\
но для уровня значимости a = 1% такое утверждение сделать нельзя - т.е. говорим что не сушествует различий в росте.')
# Out:
# Т.к. p_value = 0.01048, то для уровня значимости a = 5%
# можно сказать, что есть различия в росте между спортсмена разных видов спорта
# но для уровня значимости a = 1% такое утверждение сделать нельзя - т.е. говорим что не сушествует различий в росте.
